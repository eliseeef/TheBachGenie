# %%
import pandas as pd


def load_data_into_df():

    instagram_winners_df = pd.read_csv('./pre_processing/instagram_data/winners.csv')
    instagram_bachelors_df = pd.read_csv('./pre_processing/instagram_data/bachelors.csv')

    contestants_generalized = pd.read_csv('./pre_processing/contestants_generalized.csv')
    contestants_processed = pd.read_csv('./pre_processing/contestants_processed.csv')

    bachelors = pd.read_csv('./pre_processing/bachelors.csv')

    # Some people are missing from the generalized data, because we don't have all seasons
    print('Missing from generalized data:')
    for row in instagram_winners_df.iterrows():
        name = row[1]['name']
        name_in_generalized = contestants_generalized[contestants_generalized['name'] == name]
        if name_in_generalized.empty:
            print(f'{name}')

    print('\n\n\n')

    # Contestants with Discretization
    print(contestants_generalized.head(), end="\n\n\n")
    # Cleaned data without Discretization
    print(contestants_processed.head(), end="\n\n\n")
    # Instagram/Twitter data for winners and follower ups
    print(instagram_winners_df.head(), end="\n\n\n")
    # Instagram/Twitter data for bachelors
    print(instagram_bachelors_df.head(),end="\n\n\n")
    # Bachelor data
    print(bachelors.head(),end="\n\n\n")


load_data_into_df()
# Out:
# Missing from generalized data:
# Jennifer Schefft
# Kirsten Buschbacher
# Estelle Gardinier
# Kelly Jo Kuharski
# Mary Delgado
# Tanya Michel
# Sarah Brice
# Krisily Kennedy
# Sarah Stone
# Moana Dixon
# Bevin Powers
# Emily Maynard
# Chantal OBrien
# Courtney Robertson
# Lindzi Cox
#
#
#
#
#    season             name   age hometown             job    outcome
# 0       1     Amanda Marsh  23.0  Midwest  Event Planning     winner
# 1       1      Trista Rehn  29.0  Midwest   Entertainment   runnerUp
# 2       1   Shannon Oliver  24.0    South         Finance    midExit
# 3       1  Kimberly Karels  24.0     West       Childcare  earlyExit
# 4       1     Cathy Grimes  22.0  Midwest       Education  earlyExit
#
#
#    season             name   age              hometown  \
# 0       1     Amanda Marsh  23.0       Chanute, Kansas
# 1       1      Trista Rehn  29.0   St. Louis, Missouri
# 2       1   Shannon Oliver  24.0         Dallas, Texas
# 3       1  Kimberly Karels  24.0        Tempe, Arizona
# 4       1     Cathy Grimes  22.0  Terre Haute, Indiana
#
#                                job   outcome
# 0                    Event Planner    winner
# 1                Miami Heat Dancer  runnerUp
# 2  Financial Management Consultant         5
# 3                            Nanny         4
# 4                 Graduate Student         3
#
#
#                  name  season hair_color eye_color  instagram_followers  \
# 0        Amanda Marsh       1     blonde     green               1757.0
# 1         Trista Rehn       1      brown     brown             396000.0
# 2  Helene Eksterowicz       2      brown     brown                  NaN
# 3        Brooke Smith       2     blonde      blue               4335.0
# 4    Jennifer Schefft       3     blonde     hazel               3646.0
#
#    twitter_followers ethnicity winner
# 0                NaN     white    yes
# 1           118400.0     white     no
# 2               14.0     white    yes
# 3             2525.0     white     no
# 4             5751.0     white    yes
#
#
#                name  season hair_color eye_color  instagram_followers  \
# 0       Alex Michel       1      brown     hazel                  NaN
# 1      Aaron Buerge       2      brown     hazel                424.0
# 2  Andrew Firestone       3      brown     brown              12100.0
# 3        Bob Guiney       4      brown     brown             145000.0
# 4      Jesse Palmer       5      black      blue             272000.0
#
#    twitter_followers ethnicity
# 0                NaN     white
# 1                NaN     white
# 2              189.0     white
# 3            28200.0     white
# 4            43700.0     white
#
#
#    season              name  age                   hometown   region  \
# 0       1       Alex Michel   31  Charlottesville, Virginia    South
# 1       2      Aaron Buerge   28           Butler, Missouri  Midwest
# 2       3  Andrew Firestone   27  Santa Barbara, California     West
# 3       4        Bob Guiney   32        Riverview, Michigan  Midwest
# 4       5      Jesse Palmer   25           Toronto, Ontario  Foreign
#
#                                    job_title job_title_to_category
# 0                      Management consultant   Business/Consulting
# 1                                     Banker               Finance
# 2  Sales manager of Firestone Family estates           Real Estate
# 3              Creator of a mortgage company               Finance
# 4                    College football player                Sports
